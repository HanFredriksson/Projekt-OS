# %%
import pandas as pd
from pathlib import Path  


os_data = pd.read_csv("../Projekt-OS/Data/athlete_events.csv")

# %%
os_data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# ### OS Projekt Uppgift O

# %%
def data_printer(data):
    for i in range(0, len(data), 5):
        print(f"{', ' .join(data[i: i+5])}\n")

# %%
def data_fetcher(data, typ):
    fetch_list = []
    for i in os_data[typ]:
        if i not in fetch_list:
            fetch_list.append(i)
    return fetch_list

# %%
# A
noc_list = data_fetcher(os_data, "NOC")


print (f"Det finns: {len(noc_list)} länder i tabellen")
# Out:
# Det finns: 230 länder i tabellen

# %%
# B

print("Länder i OS")
print("-------------------\n")
data_printer(noc_list)
# Out:
# Länder i OS
# -------------------
#
# CHN, DEN, NED, USA, FIN
#
# NOR, ROU, EST, FRA, MAR
#
# ESP, EGY, IRI, BUL, ITA
#
# CHA, AZE, SUD, RUS, ARG
#
# CUB, BLR, GRE, CMR, TUR
#
# CHI, MEX, URS, NCA, HUN
#
# NGR, ALG, KUW, BRN, PAK
#
# IRQ, UAR, LIB, QAT, MAS
#
# GER, CAN, IRL, AUS, RSA
#
# ERI, TAN, JOR, TUN, LBA
#
# BEL, DJI, PLE, COM, KAZ
#
# BRU, IND, KSA, SYR, MDV
#
# ETH, UAE, YAR, INA, PHI
#
# SGP, UZB, KGZ, TJK, EUN
#
# JPN, CGO, SUI, BRA, FRG
#
# GDR, MON, ISR, URU, SWE
#
# ISV, SRI, ARM, CIV, KEN
#
# BEN, UKR, GBR, GHA, SOM
#
# LAT, NIG, MLI, AFG, POL
#
# CRC, PAN, GEO, SLO, CRO
#
# GUY, NZL, POR, PAR, ANG
#
# VEN, COL, BAN, PER, ESA
#
# PUR, UGA, HON, ECU, TKM
#
# MRI, SEY, TCH, LUX, MTN
#
# CZE, SKN, TTO, DOM, VIN
#
# JAM, LBR, SUR, NEP, MGL
#
# AUT, PLW, LTU, TOG, NAM
#
# AHO, ISL, ASA, SAM, RWA
#
# DMA, HAI, MLT, CYP, GUI
#
# BIZ, YMD, KOR, THA, BER
#
# ANZ, SCG, SLE, PNG, YEM
#
# IOA, OMA, FIJ, VAN, MDA
#
# YUG, BAH, GUA, SRB, IVB
#
# MOZ, CAF, MAD, MAL, BIH
#
# ...

# %%
# C 

os_data.dtypes
sport_list = data_fetcher(os_data, "Sport")


print("Sporter i OS")
print("-------------------\n")
data_printer(sport_list)
# Out:
# Sporter i OS
# -------------------
#
# Basketball, Judo, Football, Tug-Of-War, Speed Skating
#
# Cross Country Skiing, Athletics, Ice Hockey, Swimming, Badminton
#
# Sailing, Biathlon, Gymnastics, Art Competitions, Alpine Skiing
#
# Handball, Weightlifting, Wrestling, Luge, Water Polo
#
# Hockey, Rowing, Bobsleigh, Fencing, Equestrianism
#
# Shooting, Boxing, Taekwondo, Cycling, Diving
#
# Canoeing, Tennis, Modern Pentathlon, Figure Skating, Golf
#
# Softball, Archery, Volleyball, Synchronized Swimming, Table Tennis
#
# Nordic Combined, Baseball, Rhythmic Gymnastics, Freestyle Skiing, Rugby Sevens
#
# Trampolining, Beach Volleyball, Triathlon, Ski Jumping, Curling
#
# Snowboarding, Rugby, Short Track Speed Skating, Skeleton, Lacrosse
#
# Polo, Cricket, Racquets, Motorboating, Military Ski Patrol
#
# Croquet, Jeu De Paume, Roque, Alpinism, Basque Pelota
#
# Aeronautics

# %%
# D

medal_list = data_fetcher(os_data, "Medal")
medal_list.pop(0)
print("Medaljer i OS")
print("-------------")
data_printer(medal_list)
# Out:
# Medaljer i OS
# -------------
# Gold, Bronze, Silver

# %%
# E

stata_age = os_data["Age"].agg(["mean","median", "max", "min", "std"])

stata_age.rename({"std": "Standard divation", 
                  "mean": "Average",
                  "max" : "Oldest",
                  "min": "Youngest",
                  "median": "Meadin"})
# Out:
# Average              25.556898
# Meadin               24.000000
# Oldest               97.000000
# Youngest             10.000000
# Standard divation     6.393561
# Name: Age, dtype: float64

# %%
# F

os_data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# F

city_list = data_fetcher(os_data, "City")
city_list.sort()
print("Städer som haft OS")
print("------------------")
data_printer(city_list)
# Out:
# Städer som haft OS
# ------------------
# Albertville, Amsterdam, Antwerpen, Athina, Atlanta
#
# Barcelona, Beijing, Berlin, Calgary, Chamonix
#
# Cortina d'Ampezzo, Garmisch-Partenkirchen, Grenoble, Helsinki, Innsbruck
#
# Lake Placid, Lillehammer, London, Los Angeles, Melbourne
#
# Mexico City, Montreal, Moskva, Munich, Nagano
#
# Oslo, Paris, Rio de Janeiro, Roma, Salt Lake City
#
# Sankt Moritz, Sapporo, Sarajevo, Seoul, Sochi
#
# Squaw Valley, St. Louis, Stockholm, Sydney, Tokyo
#
# Torino, Vancouver

# %%
# F

os_data["Sex"].value_counts().rename({"M" : "Male", "F": "Female"})
# Out:
# Sex
# Male      196594
# Female     74522
# Name: count, dtype: int64

# %%
# g

os_sex_data = os_data["Sex"].value_counts().rename({"M" : "Male", "F": "Female"})   

os_sex_data = pd.DataFrame(os_sex_data)

import seaborn as sns
import matplotlib.pyplot as plt
 

sns.barplot(x = 'Sex',
            y = 'count',
            data = os_sex_data,
            )
 
plt.show()

# %%
# h
top_10_countries = os_data[os_data['Medal'].notnull()]
top_10_countries = os_data['NOC'].value_counts()
top_10_countries.head(10)
# Out:
# NOC
# USA    18853
# FRA    12758
# GBR    12256
# ITA    10715
# GER     9830
# CAN     9733
# JPN     8444
# SWE     8339
# AUS     7638
# HUN     6607
# Name: count, dtype: int64

# %%
# h
import matplotlib.pyplot as plt
import numpy as np
top_10_countries.head(10).plot(kind='bar',
                            color= plt.cm.Paired(np.arange(len(top_10_countries.head(10)))),
                            title=" Top 10 Countries With Most Medals")
plt.xlabel("Country")
plt.ylabel("Total Medals")

plt.show()

# %%
# i
def diff_medal():
    top_countries_gold = os_data[os_data['Medal'] == 'Gold']['NOC'].value_counts().head(3)
    top_countries_silver = os_data[os_data['Medal'] == 'Silver']['NOC'].value_counts().head(3)
    top_countries_bronze = os_data[os_data['Medal'] == 'Bronze']['NOC'].value_counts().head(3)
    
    print(f"Top 3 countries in Gold medal: {top_countries_gold.head(3)}")
    print(f"Top 3 countries in Silver medal: {top_countries_silver.head(3)}")
    print(f"Top 3 countries in Bronze medal: {top_countries_bronze.head(3)}")
    
    medals = pd.DataFrame({
        'Gold': top_countries_gold, 
        'Silver': top_countries_silver, 
        'Bronze': top_countries_bronze
    })    
    
    return medals

# %%
medals = diff_medal()
medals.plot(kind='bar',color= ['Gold', 'silver', 'chocolate'],title= 'Top 3 countries Each Medal Category', fig='grad')
plt.xlabel("Country")
plt.ylabel("Medal Count")
plt.show()
# Out:
# Top 3 countries in Gold medal: NOC
# USA    2638
# URS    1082
# GER     745
# Name: count, dtype: int64
# Top 3 countries in Silver medal: NOC
# USA    1641
# GBR     739
# URS     732
# Name: count, dtype: int64
# Top 3 countries in Bronze medal: NOC
# USA    1358
# GER     746
# URS     689
# Name: count, dtype: int64

# %% [markdown]
# #### * In this anlysis we can see that the USA is the top country in all types medals(Gold, Silver, Bronze), and Germany is the second top country in both Gold and Silver medals, while the ussr(URS) holds the second position in Bronze medals.

# %% [markdown]
# ### OS Projekt Uppgift 1

# %%
italy_os = pd.read_csv("../Projekt-OS/Data/italy-OS-data.csv",index_col=0)

# %%
import hashlib as hl
hashes = italy_os['Name'].apply(lambda x: hl.sha256(x.encode()).hexdigest())

# %%
italy_os.insert(2,'Name_Hash', hashes)
italy_os.head(3)
# Out:
#      ID               Name                                          Name_Hash  \
# 158  62  Giovanni Abagnale  1c1026605c0607937a724d3d839d964064f6907b3b2e0e...
# 197  91     Emanuele Abate  d5ce4ad5e9aa7549d6069b66cfefa8df14d801fd845cc7...
# 198  92      Ignazio Abate  207f8f997895f35185acbd1e26fab5176d8b3dc6f3300f...
#
#     Sex   Age  Height  Weight   Team  NOC        Games  Year  Season  \
# 158   M  21.0   198.0    90.0  Italy  ITA  2016 Summer  2016  Summer
# 197   M  27.0   190.0    80.0  Italy  ITA  2012 Summer  2012  Summer
# 198   M  21.0   180.0    73.0  Italy  ITA  2008 Summer  2008  Summer
#
#                City      Sport                               Event   Medal
# 158  Rio de Janeiro     Rowing          Rowing Men's Coxless Pairs  Bronze
# 197          London  Athletics  Athletics Men's 110 metres Hurdles     NaN
# 198         Beijing   Football             Football Men's Football     NaN

# %%
comparison = (hashes == italy_os['Name_Hash']).all()
comparison
# Out:
# np.True_

# %%
# 1
italy_os.fillna(0,inplace=True)
filter_data = italy_os[italy_os['Medal'] !=0]

# %%
# 1
medal_count = filter_data.groupby('Sport')['Medal'].count().reset_index()
medal_count_sorted = medal_count[medal_count['Medal']> 100]
print(medal_count_sorted.head())

ax = medal_count_sorted.plot(kind='bar', x= 'Sport', y='Medal',
                        title= 'Sports with more then 100 medals',
                        ylabel='Number of medals',
                        color= plt.cm.Paired(np.linspace(0,1,len(medal_count_sorted))))

plt.tight_layout()
plt.show()
# Out:
#          Sport  Medal
# 11     Cycling    124
# 14     Fencing    359
# 17  Gymnastics    109
# 23      Rowing    183
# 34  Water Polo    120
